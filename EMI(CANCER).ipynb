# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip -q /content/drive/MyDrive/Blood-Cancer-Detection-CNN-master.zip -d /content/Blood-Cancer-Detection-CNN-master
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/Blood-Cancer-Detection-CNN-master.zip, /content/drive/MyDrive/Blood-Cancer-Detection-CNN-master.zip.zip or /content/drive/MyDrive/Blood-Cancer-Detection-CNN-master.zip.ZIP.

# %%
from keras.models import load_model
from keras.preprocessing import image
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
model = load_model('/content/drive/MyDrive/weights.hdf5')

model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
img = image.load_img('/content/_2_4392.jpeg', target_size=(150, 150))
imgplot = plt.imshow(img)
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
images = np.vstack([x])
probs = model.predict(images, batch_size=10)
predicted_class = np.argmax(probs, axis=1)[0]

if predicted_class == 1:
   print("Cancer")
else:
   print("Normal")

# Show the image
plt.imshow(img)
plt.axis('off')
plt.title(f'Prediction: {"Cancer" if predicted_class == 1 else "Normal"}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 17ms/step
# Cancer

# %%
img = image.load_img('/content/_5_1558.jpeg', target_size=(150, 150))
imgplot = plt.imshow(img)
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
images = np.vstack([x])
probs = model.predict(images, batch_size=10)
predicted_class = np.argmax(probs, axis=1)[0]

if predicted_class == 0:
   print("Cancer")
else:
   print("Normal")

# Show the image
plt.imshow(img)
plt.axis('off')
plt.title(f'Prediction: {"Cancer" if predicted_class == 0 else "Normal"}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 18ms/step
# Normal

# %%
import numpy as np
from keras.preprocessing import image

# Load and preprocess the image
img = image.load_img('/content/_1_4044.jpeg', target_size=(150, 150))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)

# Make predictions
probs = model.predict(x)
predicted_class = np.argmax(probs, axis=1)[0]

if predicted_class == 1:
   print("Cancer")
else:
   print("Normal")
# Out:
# 1/1 [==============================] - 0s 18ms/step
# Cancer
